# %% [markdown]
# # **Read Data from JSON**

# %%
with open("record1.json","r") as f:
    record = f.read()

# %%
record
# Out:
# ' {"101":{"Category": "Electronics", \t"Type": "Mobile", \t\t \t"Brand": "Apple",    "Model": "iPhone 12", \t    "Color": "Black",       "Price": 71999, "Quantity": 10},\n "102": {"Category": "Electronics", \t"Type": "Mobile",   \t \t"Brand": "Samsung",\t "Model": "Galaxy S10 lite","Color": "Prism Blue",  "Price": 49999, "Quantity": 15},\n "103": {"Category": "Electronics", \t"Type":\t"Mobile",  \t\t \t"Brand": "Vivo",     "Model": "V21 5G",\t\t\t"Color": "Arctic White","Price": 29990, "Quantity": 30},\n "104": {"Category": "Electronics", \t"Type": "Laptop" ,       \t"Brand": "HP",\t     "Model": "Pavilion", \t\t"Color": "Black",\t    "Price": 66990, "Quantity": 18}, \n "105": {"Category": "Electronics", \t"Type": "Camera" , \t\t \t"Brand": "Canon",    "Model": "EOS 200D",\t\t"Color": "Black",\t    "Price": 50999, "Quantity": 25}, \n "106": {"Category": "Electronics", \t"Type": "Laptop",        \t"Brand": "Dell",     "Model": "Inspiron 5410",\t"Color": "Silver",\t\t"Price": 68990, "Quantity": 30}, \n "107": {"Category": "Electronics", \t"Type": "Speaker",       \t"Brand": "JBL",\t     "Model": "Go Plus",\t\t"Color": "Black",\t\t"Price": 1699,  "Quantity": 100},\n "108": {"Category": "Electronics", \t"Type": "Tablets",       \t"Brand": "Apple",    "Model": "ipad Air",  \t\t"Color": "Sky Blue",    "Price": 51900, "Quantity": 10}, \n "109": {"Category": "Electronics", \t"Type": "Camera",        \t"Brand": "Sony",     "Model": "Cybershot",\t \t"Color": "Black",\t\t"Price": 7790,  "Quantity": 10},\n "110": {"Category": "Home Appliances", "Type": "Refrigerator",  \t"Brand": "Whirpool", "Model": "WDE",  \t\t\t"Color": "Silver",\t    "Price": 13990 ,"Quantity": 12},\n "111": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "Voltas",   "Model": "183 VCZJ(R32)",  "Color": "White",       "Price": 33990, "Quantity": 17},\n "112": {"Category": "Home Appliances", "Type": "Telivision",       "Brand": "Mi",       "Model": "4A PRO",         "Color": "Black",       "Price": 16999, "Quantity": 100},\n "113": {"Category": "Home Appliances", "Type": "Microwave",        "Brand": "Samsung",  "Model": "MS23F301TAK",    "Color": "Black",       "Price": 5685,  "Quantity": 45}, \n "114": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "Blue Star","Model": "IC315AATU",\t    "Color": "White",       "Price": 31990, "Quantity": 12}, \n "115": {"Category": "Home Appliances",\t"Type":\t"Refrigerator",     "Brand": "Haier",    "Model": "HED",\t\t    "Color": "Silver",      "Price": 14690, "Quantity": 10}, \n "116": {"Category": "Home Appliances", "Type":\t"Telivision",       "Brand": "Sony",     "Model": "Bravia X7002G",\t"Color": "Black",       "Price": 44999, "Quantity": 50},\n "117": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "LG",       "Model": "MS-Q18PNXA",     "Color": "White",       "Price": 35390, "Quantity": 5}, \n "118": {"Category": "Home Appliances", "Type":\t"Refrigerator",     "Brand": "Lloyd",    "Model": "GLSF590DGLT1LB", "Color": "Pink",        "Price": 60990, "Quantity": 10},\n "119": {"Category": "Home Appliances", "Type":\t"Washing machine",  "Brand": "Samsung",  "Model": "WW60R20GLMA/TL", "Color": "Blue",        "Price": 22899, "Quantity": 100},\n "120": {"Category": "Home Appliances", "Type":\t"Telivision",    \t"Brand": "realme",   "Model": "RMV2004",        "Color": "Black",       "Price": 30990, "Quantity": 100},\n "121": {"Category": "Home Appliances", "Type": "Air coolers", \t\t"Brand": "Symphony", "Model": "Storm 70XL-G",   "Color": "White",       "Price": 11299, "Quantity": 35}, \n "122": {"Category": "Home Appliances",\t"Type":\t"Water purifiers",  "Brand": "Kent",     "Model": "GRAND STAR",     "Color": "White",       "Price": 18273, "Quantity": 42}, \n "123": {"Category": "Electrical",      "Type": "Fan",   \t\t\t"Brand": "Havells",  "Model": "STEALTH AIR",    "Color": "Brown",       "Price": 6530,  "Quantity": 150}, \n "124": {"Category": "Electrical", \t\t"Typ ...

# %%
import json
data = json.loads(record)
data
# Out:
# {'101': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Apple',
#   'Model': 'iPhone 12',
#   'Color': 'Black',
#   'Price': 71999,
#   'Quantity': 10},
#  '102': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Samsung',
#   'Model': 'Galaxy S10 lite',
#   'Color': 'Prism Blue',
#   'Price': 49999,
#   'Quantity': 15},
#  '103': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Vivo',
#   'Model': 'V21 5G',
#   'Color': 'Arctic White',
#   'Price': 29990,
#   'Quantity': 30},
#  '104': {'Category': 'Electronics',
#   'Type': 'Laptop',
#   'Brand': 'HP',
#   'Model': 'Pavilion',
#   'Color': 'Black',
#   'Price': 66990,
#   'Quantity': 18},
#  '105': {'Category': 'Electronics',
#   'Type': 'Camera',
#   'Brand': 'Canon',
#   'Model': 'EOS 200D',
#   'Color': 'Black',
#   'Price': 50999,
#   'Quantity': 25},
#  '106': {'Category': 'Electronics',
#   'Type': 'Laptop',
#   'Brand': 'Dell',
#   'Model': 'Inspiron 5410',
#   'Color': 'Silver',
#   'Price': 68990,
#   'Quantity': 30},
#  '107': {'Category': 'Electronics',
#   'Type': 'Speaker',
#   'Brand': 'JBL',
#   'Model': 'Go Plus',
#   'Color': 'Black',
#   'Price': 1699,
#   'Quantity': 100},
#  '108': {'Category': 'Electronics',
#   'Type': 'Tablets',
#   'Brand': 'Apple',
#   'Model': 'ipad Air',
#   'Color': 'Sky Blue',
#   'Price': 51900,
#   'Quantity': 10},
#  '109': {'Category': 'Electronics',
#   'Type': 'Camera',
#   'Brand': 'Sony',
#   'Model': 'Cybershot',
#   'Color': 'Black',
#   'Price': 7790,
#   'Quantity': 10},
#  '110': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Whirpool',
#   'Model': 'WDE',
#   'Color': 'Silver',
#   'Price': 13990,
#   'Quantity': 12},
#  '111': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'Voltas',
#   'Model': '183 VCZJ(R32)',
#   'Color': 'White',
#   'Price': 33990,
#   'Quantity': 17},
#  '112': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'Mi',
#   'Model': '4A PRO',
#   'Color': 'Black',
#   'Price': 16999,
#   'Quantity': 100},
#  '113': {'Category': 'Home Appliances',
#   'Type': 'Microwave',
#   'Brand': 'Samsung',
#   'Model': 'MS23F301TAK',
#   'Color': 'Black',
#   'Price': 5685,
#   'Quantity': 45},
#  '114': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'Blue Star',
#   'Model': 'IC315AATU',
#   'Color': 'White',
#   'Price': 31990,
#   'Quantity': 12},
#  '115': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Haier',
#   'Model': 'HED',
#   'Color': 'Silver',
#   'Price': 14690,
#   'Quantity': 10},
#  '116': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'Sony',
#   'Model': 'Bravia X7002G',
#   'Color': 'Black',
#   'Price': 44999,
#   'Quantity': 50},
#  '117': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'LG',
#   'Model': 'MS-Q18PNXA',
#   'Color': 'White',
#   'Price': 35390,
#   'Quantity': 5},
#  '118': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Lloyd',
#   'Model': 'GLSF590DGLT1LB',
#   'Color': 'Pink',
#   'Price': 60990,
#   'Quantity': 10},
#  '119': {'Category': 'Home Appliances',
#   'Type': 'Washing machine',
#   'Brand': 'Samsung',
#   'Model': 'WW60R20GLMA/TL',
#   'Color': 'Blue',
#   'Price': 22899,
#   'Quantity': 100},
#  '120': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'realme',
#   'Model': 'RMV2004',
#   'Color': 'Black',
#   'Price': 30990,
#   'Quantity': 100},
#  '121': {'Category': 'Home Appliances',
#   'Type': 'Air coolers',
#   'Brand': 'Symphony',
#   'Model': 'Storm 70XL-G',
#   'Color': 'White',
#   'Price': 11299,
#   'Quantity': 35},
#  '122': {'Category': 'Home Appliances',
#   'Type': 'Water purifiers',
#   'Brand': 'Kent',
#   'Model': 'GRAND STAR',
#   'Color': 'White',
#   'Price': 18273,
#   'Quantity': 42},
#  '123': {'Category': 'Electrical',
#   'Type': 'Fan',
#   'Brand': 'Havells',
#   'Model': 'STEALTH AIR',
#   'Color': 'Brown',
#   'Price': 6530,
#   'Quantity': 150},
#  '124': {'Category': 'Electrical',
#   'Type': 'Light',
#   'Brand': 'Syska',
#   'Model': '8W-2 Feet',
#   'Color': 'White',
#   'Price': 694,
#   'Quantity': 200},
#  '125': {'Category': 'Accessories',
#   'Type': 'Smart watch',
#   'Brand': 'Apple',
#   'Model': 'Series 6',
#   'Color': 'Black',
#   'Price': 52900,
#   'Quantity': 25},
#  '126': {'Category': 'Accessories',
#   'Type': 'Smart watch',
#   'Brand': 'boAt',
#   'Model': 'Storm',
#   'Color': 'Pink',
#   'Price': 2999,
#   'Quantity': 100},
#  '127': {'Category': 'Accessories',
#   'Type': 'Headphones',
#   'Brand': 'Oneplus',
#   'Model': 'E304A',
#   'Color': 'Black',
#   'Price': 1999,
#   'Quantity': 150},
#  '128': {'Category': 'Accessories',
#   'Type': 'Powerbank',
#   'Brand': 'Mi',
#   'Model': '3i',
#   'Color': 'Black',
#   'Price': 1699,
#   'Quantity': 125},
#  '129': {'Category': 'Accessories',
#   'Type': 'Headphones',
#   'Brand': 'JBL',
#   'Model': 'T450 BT',
#   'Color': 'Blue',
#   'Price': 2499,
#   'Quantity': 110}}

# %% [markdown]
# # **Add New item into inventory**

# %%
Product_Id = input("Enter the Product Id :")
Category = input("Enter the Category :")
Type = input("Enter the type of the product :")
Brand = input("Enter the Brand name :")
Model = input("Enter the Model name :")
Color = input("Enter the Color :")
Price = int(input("Enter the Price :"))
Quantity = int(input("Enter the Quantity :"))
# Out:
# Enter the Product Id :130
# Enter the Category :Accessories
# Enter the type of the product :Headphones
# Enter the Brand name :fellkon
# Enter the Model name :i7 Twins
# Enter the Color :White
# Enter the Price :429
# Enter the Quantity :120

# %%
data[Product_Id] = {"Category": Category,
                      "Type": Type,
                      "Brand": Brand,
                      "Model": Model,
                      "Color": Color,
                      "Price": Price,
                      "Quantity": Quantity}

# %% [markdown]
# # **Adding the new product**

# %%
# Here we add Product_Id =130
data
# Out:
# {'101': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Apple',
#   'Model': 'iPhone 12',
#   'Color': 'Black',
#   'Price': 71999,
#   'Quantity': 10},
#  '102': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Samsung',
#   'Model': 'Galaxy S10 lite',
#   'Color': 'Prism Blue',
#   'Price': 49999,
#   'Quantity': 15},
#  '103': {'Category': 'Electronics',
#   'Type': 'Mobile',
#   'Brand': 'Vivo',
#   'Model': 'V21 5G',
#   'Color': 'Arctic White',
#   'Price': 29990,
#   'Quantity': 30},
#  '104': {'Category': 'Electronics',
#   'Type': 'Laptop',
#   'Brand': 'HP',
#   'Model': 'Pavilion',
#   'Color': 'Black',
#   'Price': 66990,
#   'Quantity': 18},
#  '105': {'Category': 'Electronics',
#   'Type': 'Camera',
#   'Brand': 'Canon',
#   'Model': 'EOS 200D',
#   'Color': 'Black',
#   'Price': 50999,
#   'Quantity': 25},
#  '106': {'Category': 'Electronics',
#   'Type': 'Laptop',
#   'Brand': 'Dell',
#   'Model': 'Inspiron 5410',
#   'Color': 'Silver',
#   'Price': 68990,
#   'Quantity': 30},
#  '107': {'Category': 'Electronics',
#   'Type': 'Speaker',
#   'Brand': 'JBL',
#   'Model': 'Go Plus',
#   'Color': 'Black',
#   'Price': 1699,
#   'Quantity': 100},
#  '108': {'Category': 'Electronics',
#   'Type': 'Tablets',
#   'Brand': 'Apple',
#   'Model': 'ipad Air',
#   'Color': 'Sky Blue',
#   'Price': 51900,
#   'Quantity': 10},
#  '109': {'Category': 'Electronics',
#   'Type': 'Camera',
#   'Brand': 'Sony',
#   'Model': 'Cybershot',
#   'Color': 'Black',
#   'Price': 7790,
#   'Quantity': 10},
#  '110': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Whirpool',
#   'Model': 'WDE',
#   'Color': 'Silver',
#   'Price': 13990,
#   'Quantity': 12},
#  '111': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'Voltas',
#   'Model': '183 VCZJ(R32)',
#   'Color': 'White',
#   'Price': 33990,
#   'Quantity': 17},
#  '112': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'Mi',
#   'Model': '4A PRO',
#   'Color': 'Black',
#   'Price': 16999,
#   'Quantity': 100},
#  '113': {'Category': 'Home Appliances',
#   'Type': 'Microwave',
#   'Brand': 'Samsung',
#   'Model': 'MS23F301TAK',
#   'Color': 'Black',
#   'Price': 5685,
#   'Quantity': 45},
#  '114': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'Blue Star',
#   'Model': 'IC315AATU',
#   'Color': 'White',
#   'Price': 31990,
#   'Quantity': 12},
#  '115': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Haier',
#   'Model': 'HED',
#   'Color': 'Silver',
#   'Price': 14690,
#   'Quantity': 10},
#  '116': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'Sony',
#   'Model': 'Bravia X7002G',
#   'Color': 'Black',
#   'Price': 44999,
#   'Quantity': 50},
#  '117': {'Category': 'Home Appliances',
#   'Type': 'Air conditioners',
#   'Brand': 'LG',
#   'Model': 'MS-Q18PNXA',
#   'Color': 'White',
#   'Price': 35390,
#   'Quantity': 5},
#  '118': {'Category': 'Home Appliances',
#   'Type': 'Refrigerator',
#   'Brand': 'Lloyd',
#   'Model': 'GLSF590DGLT1LB',
#   'Color': 'Pink',
#   'Price': 60990,
#   'Quantity': 10},
#  '119': {'Category': 'Home Appliances',
#   'Type': 'Washing machine',
#   'Brand': 'Samsung',
#   'Model': 'WW60R20GLMA/TL',
#   'Color': 'Blue',
#   'Price': 22899,
#   'Quantity': 100},
#  '120': {'Category': 'Home Appliances',
#   'Type': 'Telivision',
#   'Brand': 'realme',
#   'Model': 'RMV2004',
#   'Color': 'Black',
#   'Price': 30990,
#   'Quantity': 100},
#  '121': {'Category': 'Home Appliances',
#   'Type': 'Air coolers',
#   'Brand': 'Symphony',
#   'Model': 'Storm 70XL-G',
#   'Color': 'White',
#   'Price': 11299,
#   'Quantity': 35},
#  '122': {'Category': 'Home Appliances',
#   'Type': 'Water purifiers',
#   'Brand': 'Kent',
#   'Model': 'GRAND STAR',
#   'Color': 'White',
#   'Price': 18273,
#   'Quantity': 42},
#  '123': {'Category': 'Electrical',
#   'Type': 'Fan',
#   'Brand': 'Havells',
#   'Model': 'STEALTH AIR',
#   'Color': 'Brown',
#   'Price': 6530,
#   'Quantity': 150},
#  '124': {'Category': 'Electrical',
#   'Type': 'Light',
#   'Brand': 'Syska',
#   'Model': '8W-2 Feet',
#   'Color': 'White',
#   'Price': 694,
#   'Quantity': 200},
#  '125': {'Category': 'Accessories',
#   'Type': 'Smart watch',
#   'Brand': 'Apple',
#   'Model': 'Series 6',
#   'Color': 'Black',
#   'Price': 52900,
#   'Quantity': 25},
#  '126': {'Category': 'Accessories',
#   'Type': 'Smart watch',
#   'Brand': 'boAt',
#   'Model': 'Storm',
#   'Color': 'Pink',
#   'Price': 2999,
#   'Quantity': 100},
#  '127': {'Category': 'Accessories',
#   'Type': 'Headphones',
#   'Brand': 'Oneplus',
#   'Model': 'E304A',
#   'Color': 'Black',
#   'Price': 1999,
#   'Quantity': 150},
#  '128': {'Category': 'Accessories',
#   'Type': 'Powerbank',
#   'Brand': 'Mi',
#   'Model': '3i',
#   'Color': 'Black',
#   'Price': 1699,
#   'Quantity': 125},
#  '129': {'Category': 'Accessories',
#   'Type': 'Headphones',
#   'Brand': 'JBL',
#   'Model': 'T450 BT',
#   'Color': 'Blue',
#   'Price': 2499,
#   'Quantity': 110},
#  '130': {'Category': 'Accessories',
#   'Type': 'Headphones',
#   'Brand': 'fellkon',
#   'Model': 'i7 Twins',
#   'Color': 'White',
#   'Price': 429,
#   'Quantity': 120}}

# %%
# dump the record into record.jason
js = json.dumps(data)
js
# Out:
# '{"101": {"Category": "Electronics", "Type": "Mobile", "Brand": "Apple", "Model": "iPhone 12", "Color": "Black", "Price": 71999, "Quantity": 10}, "102": {"Category": "Electronics", "Type": "Mobile", "Brand": "Samsung", "Model": "Galaxy S10 lite", "Color": "Prism Blue", "Price": 49999, "Quantity": 15}, "103": {"Category": "Electronics", "Type": "Mobile", "Brand": "Vivo", "Model": "V21 5G", "Color": "Arctic White", "Price": 29990, "Quantity": 30}, "104": {"Category": "Electronics", "Type": "Laptop", "Brand": "HP", "Model": "Pavilion", "Color": "Black", "Price": 66990, "Quantity": 18}, "105": {"Category": "Electronics", "Type": "Camera", "Brand": "Canon", "Model": "EOS 200D", "Color": "Black", "Price": 50999, "Quantity": 25}, "106": {"Category": "Electronics", "Type": "Laptop", "Brand": "Dell", "Model": "Inspiron 5410", "Color": "Silver", "Price": 68990, "Quantity": 30}, "107": {"Category": "Electronics", "Type": "Speaker", "Brand": "JBL", "Model": "Go Plus", "Color": "Black", "Price": 1699, "Quantity": 100}, "108": {"Category": "Electronics", "Type": "Tablets", "Brand": "Apple", "Model": "ipad Air", "Color": "Sky Blue", "Price": 51900, "Quantity": 10}, "109": {"Category": "Electronics", "Type": "Camera", "Brand": "Sony", "Model": "Cybershot", "Color": "Black", "Price": 7790, "Quantity": 10}, "110": {"Category": "Home Appliances", "Type": "Refrigerator", "Brand": "Whirpool", "Model": "WDE", "Color": "Silver", "Price": 13990, "Quantity": 12}, "111": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "Voltas", "Model": "183 VCZJ(R32)", "Color": "White", "Price": 33990, "Quantity": 17}, "112": {"Category": "Home Appliances", "Type": "Telivision", "Brand": "Mi", "Model": "4A PRO", "Color": "Black", "Price": 16999, "Quantity": 100}, "113": {"Category": "Home Appliances", "Type": "Microwave", "Brand": "Samsung", "Model": "MS23F301TAK", "Color": "Black", "Price": 5685, "Quantity": 45}, "114": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "Blue Star", "Model": "IC315AATU", "Color": "White", "Price": 31990, "Quantity": 12}, "115": {"Category": "Home Appliances", "Type": "Refrigerator", "Brand": "Haier", "Model": "HED", "Color": "Silver", "Price": 14690, "Quantity": 10}, "116": {"Category": "Home Appliances", "Type": "Telivision", "Brand": "Sony", "Model": "Bravia X7002G", "Color": "Black", "Price": 44999, "Quantity": 50}, "117": {"Category": "Home Appliances", "Type": "Air conditioners", "Brand": "LG", "Model": "MS-Q18PNXA", "Color": "White", "Price": 35390, "Quantity": 5}, "118": {"Category": "Home Appliances", "Type": "Refrigerator", "Brand": "Lloyd", "Model": "GLSF590DGLT1LB", "Color": "Pink", "Price": 60990, "Quantity": 10}, "119": {"Category": "Home Appliances", "Type": "Washing machine", "Brand": "Samsung", "Model": "WW60R20GLMA/TL", "Color": "Blue", "Price": 22899, "Quantity": 100}, "120": {"Category": "Home Appliances", "Type": "Telivision", "Brand": "realme", "Model": "RMV2004", "Color": "Black", "Price": 30990, "Quantity": 100}, "121": {"Category": "Home Appliances", "Type": "Air coolers", "Brand": "Symphony", "Model": "Storm 70XL-G", "Color": "White", "Price": 11299, "Quantity": 35}, "122": {"Category": "Home Appliances", "Type": "Water purifiers", "Brand": "Kent", "Model": "GRAND STAR", "Color": "White", "Price": 18273, "Quantity": 42}, "123": {"Category": "Electrical", "Type": "Fan", "Brand": "Havells", "Model": "STEALTH AIR", "Color": "Brown", "Price": 6530, "Quantity": 150}, "124": {"Category": "Electrical", "Type": "Light", "Brand": "Syska", "Model": "8W-2 Feet", "Color": "White", "Price": 694, "Quantity": 200}, "125": {"Category": "Accessories", "Type": "Smart watch", "Brand": "Apple", "Model": "Series 6", "Color": "Black", "Price": 52900, "Quantity": 25}, "126": {"Category": "Accessories", "Type": "Smart watch", "Brand": "boAt", "Model": "Storm", "Color": "Pink", "Price": 2999, "Quantity": 100}, "127": {"Category": "Accessories", "Type": "Headphones", "Brand": "Oneplus", "Model":  ...

# %% [markdown]
# # **Now over-write the previous file**

# %%
with open("record.json","w") as file:
    file.write(js)
